# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install io
# Out:
# ERROR: Could not find a version that satisfies the requirement io (from versions: none)
# ERROR: No matching distribution found for io
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import lxml
import requests

# %%
import yfinance as yf

# %%
url= "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
headers= {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

# %%
response=requests.get(url, headers=headers)

sp500=pd.read_html(StringIO(response.text))[0]
sp500
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
sp500.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Symbol                 503 non-null    str
#  1   Security               503 non-null    str
#  2   GICS Sector            503 non-null    str
#  3   GICS Sub-Industry      503 non-null    str
#  4   Headquarters Location  503 non-null    str
#  5   Date added             503 non-null    str
#  6   CIK                    503 non-null    int64
#  7   Founded                503 non-null    str
# dtypes: int64(1), str(7)
# memory usage: 31.6 KB

# %%
sp500['Symbol']=sp500['Symbol'].str.replace(".", "-", regex=False)

# %%
# list of ticker symbols for download (Needs to be done for S&P 500)
tickerStrings = sp500['Symbol'].tolist()

# %%
df = yf.download(tickerStrings, group_by='Ticker', period='5d')
# Out:
# [                       1%                       ]  4 of 503 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df = yf.download(tickerStrings, group_by='Ticker', period='5d')
#
# File ~/Finance-Data-Platform/.venv/lib/python3.12/site-packages/yfinance/utils.py:123, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     120 logger.debug(f'Entering {func.__name__}()')
#     122 with IndentationContext():
# --> 123     result = func(*args, **kwargs)
#     125 logger.debug(f'Exiting {func.__name__}()')
#     126 return result
#
# File ~/Finance-Data-Platform/.venv/lib/python3.12/site-packages/yfinance/multi.py:110, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, interval, prepost, rounding, timeout, session, multi_level_index)
# ...

# %%
df
# Out:
# Ticker             TYL                                               \
# Price             Open        High         Low       Close   Volume
# Date
# 2026-05-19  328.420013  330.920013  318.429993  322.739990  1005200
# 2026-05-20  316.600006  317.959991  310.149994  317.260010   622600
# 2026-05-21  313.290009  313.290009  305.000000  308.739990   514400
# 2026-05-22  309.700012  316.820007  309.529999  313.250000   357900
# 2026-05-26  309.329987  311.630005  305.750000  307.390015   650100
# 2026-05-27  306.000000  310.630005  299.829987  302.549988   626900
# 2026-05-28  303.880005  310.540009  301.160004  306.040009   654500
# 2026-05-29  305.619995  313.260010  302.470001  313.149994  1217400
# 2026-06-01  321.890015  331.540009  317.309998  329.829987   780900
# 2026-06-02  321.690002  322.500000  307.140015  313.559998   645100
# 2026-06-03  310.010010  310.600006  298.950012  303.769989   653600
# 2026-06-04  310.850006  314.559998  306.170013  308.149994   691700
# ...

# %%
df = df.stack(level=0).rename_axis(['Date', 'Ticker']).reset_index()
df
# Out:
# Price       Date Ticker         Open         High          Low        Close  \
# 0     2026-05-19    TYL   328.420013   330.920013   318.429993   322.739990
# 1     2026-05-19   FLEX   125.410004   128.389999   121.300003   126.290001
# 2     2026-05-19    KHC    22.949067    23.165150    22.595475    22.865582
# 3     2026-05-19   DELL   234.250000   239.750000   227.270004   235.259995
# 4     2026-05-19   GNRC   247.669998   248.750000   238.179993   243.970001
# ...          ...    ...          ...          ...          ...          ...
# 11061 2026-06-18    MAR          NaN          NaN          NaN          NaN
# 11062 2026-06-18     EG          NaN          NaN          NaN          NaN
# 11063 2026-06-18   MPWR  1529.239990  1581.040039  1515.619995  1563.699951
# 11064 2026-06-18   KVUE          NaN          NaN          NaN          NaN
# 11065 2026-06-18    HPE    49.174999    49.599998    46.930000    47.410000
#
# Price      Volume  Adj Close
# ...

# %%
df.columns.name = None
df
# Out:
#             Date Ticker         Open         High          Low        Close  \
# 0     2026-05-19    TYL   328.420013   330.920013   318.429993   322.739990
# 1     2026-05-19   FLEX   125.410004   128.389999   121.300003   126.290001
# 2     2026-05-19    KHC    22.949067    23.165150    22.595475    22.865582
# 3     2026-05-19   DELL   234.250000   239.750000   227.270004   235.259995
# 4     2026-05-19   GNRC   247.669998   248.750000   238.179993   243.970001
# ...          ...    ...          ...          ...          ...          ...
# 11061 2026-06-18    MAR          NaN          NaN          NaN          NaN
# 11062 2026-06-18     EG          NaN          NaN          NaN          NaN
# 11063 2026-06-18   MPWR  1529.239990  1581.040039  1515.619995  1563.699951
# 11064 2026-06-18   KVUE          NaN          NaN          NaN          NaN
# 11065 2026-06-18    HPE    49.174999    49.599998    46.930000    47.410000
#
#            Volume  Adj Close
# ...

# %%
test = yf.download(["BRK-B","BF-B"], period="5d")
print(test)
# Out:
# [*********************100%***********************]  1 of 2 completed
# Price           Close                   High                    Low  \
# Ticker           BF-B       BRK-B       BF-B       BRK-B       BF-B
# Date
# 2026-06-12  27.010000  489.250000  27.080000  489.989990  26.450001
# 2026-06-15  26.940001  495.519989  27.360001  497.109985  26.879999
# 2026-06-16  26.610001  494.950012  27.230000  499.790009  26.469999
# 2026-06-17  25.510000  491.279999  26.580000  494.769989  25.270000
# 2026-06-18        NaN  489.459991        NaN  493.570007        NaN
#
# Price                        Open               Volume
# Ticker           BRK-B       BF-B       BRK-B     BF-B    BRK-B
# Date
# 2026-06-12  484.510010  26.709999  486.670013  2186600  4591300
# 2026-06-15  487.559998  26.940001  487.559998  2981100  6253600
# 2026-06-16  492.429993  27.030001  497.000000  2147000  4345900
# 2026-06-17  487.899994  26.480000  493.239990  3038200  5412000
# ...

# %%
dotted = sp500.loc[sp500["Symbol"].str.contains(".", regex=False), "Symbol"]
print(dotted.tolist())
# Out:
# ['BRK.B', 'BF.B']

# %%
sp500['Symbol']=sp500['Symbol'].str.replace(".", "-", regex=False)

# %%
dotted = sp500.loc[sp500["Symbol"].str.contains(".", regex=False), "Symbol"]
print(dotted.tolist())
# Out:
# []

# %%
test = yf.download("EXPE", period="5d")
print(test)

test2 = yf.download("CNC", period="5d")
print(test2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open   Volume
# Ticker            EXPE        EXPE        EXPE        EXPE     EXPE
# Date
# 2026-06-12  224.889999  229.740005  220.490005  226.350006  1257400
# 2026-06-15  236.979996  239.490005  229.229996  229.899994  1675300
# 2026-06-16  243.559998  246.500000  237.089996  237.089996  1778900
# 2026-06-17  239.470001  244.360001  238.809998  241.880005  1174300
# 2026-06-18         NaN         NaN         NaN         NaN  2771206
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker            CNC        CNC        CNC        CNC       CNC
# Date
# 2026-06-12  65.190002  65.910004  63.270000  64.190002   4784300
# 2026-06-15  63.400002  65.110001  62.209999  64.620003   6468500
# 2026-06-16  61.389999  63.880001  60.529999  63.230000   6162900
# ...
